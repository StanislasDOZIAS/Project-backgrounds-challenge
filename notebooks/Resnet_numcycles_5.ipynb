# %%
import sys  
sys.path.insert(0, '../')
from tools.training import make_training, test_on_dataset
from imagenet_models.resnet import resnet18

import torch.nn as nn
import torch

# %%
variation = "original"

# %%
net = resnet18(pretrained=True)
temp_net = resnet18(pretrained=False)

# %%
net.fc = nn.Linear(512, 9)
temp_net.fc = nn.Linear(512, 9)

# %%
n_epoch_first_train = 10
n_cycle = 5
n_epoch_cycle = 5

# %%
make_training(variation,
              net,
              temp_net,
              n_epoch_first_train = n_epoch_first_train,
              n_cycle = n_cycle,
              n_epoch_cycle = n_epoch_cycle,
              batch_size = 16,
              workers = 0,
              criterion = nn.CrossEntropyLoss(),
              test_acc_period = 5,
              _print = False)
# Out:
# using cuda
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Finished Training
# Final acc :  100.0
#
# Accuracy Graph
# Loss Graph
# Learning Rate Curve

# %%
PATH = "../models/ResNet_numcycle_" + str(n_cycle) + "_noSWA.pt"
torch.save(net.state_dict(), PATH)

PATH = "../models/ResNet_numcycle_" + str(n_cycle) + "_SWA.pt"
torch.save(temp_net.state_dict(), PATH)

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  100.0
# Accuracy on  mixed_same  :  93.11111111111111
# Accuracy on  mixed_next  :  80.17283950617283
# Accuracy on  mixed_rand  :  82.69135802469135
# Accuracy on  no_fg  :  64.61728395061728
# Accuracy on  only_bg_b  :  31.85185185185185
# Accuracy on  only_bg_t  :  39.60493827160494
# Accuracy on  only_fg  :  94.76543209876543

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=temp_net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  100.0
# Accuracy on  mixed_same  :  94.32098765432099
# Accuracy on  mixed_next  :  82.41975308641975
# Accuracy on  mixed_rand  :  84.69135802469135
# Accuracy on  no_fg  :  63.901234567901234
# Accuracy on  only_bg_b  :  33.65432098765432
# Accuracy on  only_bg_t  :  39.18518518518518
# Accuracy on  only_fg  :  96.66666666666667

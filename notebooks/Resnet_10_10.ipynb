# %%
import sys  
sys.path.insert(0, '../')
from tools.training import make_training, test_on_dataset
from imagenet_models.resnet import resnet18

import torch.nn as nn
import torch

# %%
variation = "original"

# %%
net = resnet18(pretrained=True)
temp_net = resnet18(pretrained=False)

# %%
net.fc = nn.Linear(512, 9)
temp_net.fc = nn.Linear(512, 9)

# %%
n_epoch_first_train = 10
n_cycle = 10
n_epoch_cycle = 10

# %%
make_training(variation,
              net,
              temp_net,
              n_epoch_first_train = n_epoch_first_train,
              n_cycle = n_cycle, 
              n_epoch_cycle = n_epoch_cycle,
              batch_size = 16,
              workers = 0,
              criterion = nn.CrossEntropyLoss(),
              test_acc_period = 5,
              _print = False)
# Out:
# using cuda
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Finished Training
# Final acc :  99.9753086419753
#
# Accuracy Graph
# Loss Graph
# Learning Rate Curve

# %%
PATH = "../models/ResNet_longcycle_" + str(n_epoch_cycle) + "_noSWA.pt"
torch.save(net.state_dict(), PATH)

PATH = "../models/ResNet_longcycle_" + str(n_epoch_cycle) + "_SWA.pt"
torch.save(temp_net.state_dict(), PATH)

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  99.9753086419753
# Accuracy on  mixed_same  :  89.08641975308642
# Accuracy on  mixed_next  :  72.32098765432099
# Accuracy on  mixed_rand  :  75.67901234567901
# Accuracy on  no_fg  :  54.44444444444444
# Accuracy on  only_bg_b  :  26.444444444444443
# Accuracy on  only_bg_t  :  34.34567901234568
# Accuracy on  only_fg  :  91.55555555555556

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=temp_net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  100.0
# Accuracy on  mixed_same  :  93.90123456790124
# Accuracy on  mixed_next  :  81.06172839506173
# Accuracy on  mixed_rand  :  83.92592592592592
# Accuracy on  no_fg  :  66.07407407407408
# Accuracy on  only_bg_b  :  34.34567901234568
# Accuracy on  only_bg_t  :  37.45679012345679
# Accuracy on  only_fg  :  95.11111111111111

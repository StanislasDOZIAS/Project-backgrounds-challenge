# %%
import sys  
sys.path.insert(0, '../')
from tools.training import make_training, test_on_dataset
from imagenet_models.resnet import resnet18

import torch.nn as nn
import torch

# %%
variation = "original"

# %%
net = resnet18(pretrained=True)
temp_net = resnet18(pretrained=False)

# %%
net.fc = nn.Linear(512, 9)
temp_net.fc = nn.Linear(512, 9)

# %%
n_epoch_first_train = 10
n_cycle = 10
n_epoch_cycle = 5

# %%
make_training(variation,
              net,
              temp_net,
              n_epoch_first_train = n_epoch_first_train,
              n_cycle = n_cycle,
              n_epoch_cycle = n_epoch_cycle,
              batch_size = 16,
              workers = 0,
              criterion = nn.CrossEntropyLoss(),
              test_acc_period = 5,
              _print = False)
# Out:
# using cuda
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Finished Training
# Final acc :  100.0
#
# Accuracy Graph
# Loss Graph
# Learning Rate Curve

# %%
PATH = "../models/ResNet_longcycle_" + str(n_epoch_cycle) + "_noSWA.pt"
torch.save(net.state_dict(), PATH)

PATH = "../models/ResNet_longcycle_" + str(n_epoch_cycle) + "_SWA.pt"
torch.save(temp_net.state_dict(), PATH)

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  100.0
# Accuracy on  mixed_same  :  87.90123456790124
# Accuracy on  mixed_next  :  73.33333333333333
# Accuracy on  mixed_rand  :  75.85185185185185
# Accuracy on  no_fg  :  57.03703703703704
# Accuracy on  only_bg_b  :  28.17283950617284
# Accuracy on  only_bg_t  :  33.80246913580247
# Accuracy on  only_fg  :  91.33333333333333

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=temp_net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  100.0
# Accuracy on  mixed_same  :  93.9753086419753
# Accuracy on  mixed_next  :  82.46913580246914
# Accuracy on  mixed_rand  :  84.17283950617283
# Accuracy on  no_fg  :  65.1358024691358
# Accuracy on  only_bg_b  :  31.234567901234566
# Accuracy on  only_bg_t  :  38.148148148148145
# Accuracy on  only_fg  :  95.75308641975309

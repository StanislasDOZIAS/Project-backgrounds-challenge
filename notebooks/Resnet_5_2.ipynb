# %%
import sys  
sys.path.insert(0, '../')
from tools.training import make_training, test_on_dataset
from imagenet_models.resnet import resnet18

import torch.nn as nn
import torch

# %%
variation = "original"

# %%
net = resnet18(pretrained=True)
temp_net = resnet18(pretrained=False)

# %%
net.fc = nn.Linear(512, 9)
temp_net.fc = nn.Linear(512, 9)

# %%
net.load_state_dict(torch.load("../models/ResNet_base_noSWA.pt"))
# Out:
# <All keys matched successfully>

# %%
n_epoch_first_train = 0
n_cycle = 5
n_epoch_cycle = 2

# %%
make_training(variation,
              net,
              temp_net,
              n_epoch_first_train = n_epoch_first_train,
              n_cycle = n_cycle,
              n_epoch_cycle = n_epoch_cycle,
              batch_size = 16,
              workers = 0,
              criterion = nn.CrossEntropyLoss(),
              test_acc_period = 5,
              _print = False)
# Out:
# using cuda
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# Finished Training
# Final acc :  99.87654320987654
#
# Accuracy Graph
# Loss Graph
# Learning Rate Curve

# %%
PATH = "../models/ResNet_" + str(n_cycle) + "_" + str(n_epoch_cycle)  + "_noSWA.pt"
torch.save(net.state_dict(), PATH)

PATH = "../models/ResNet_" + str(n_cycle)  + "_" + str(n_epoch_cycle)  + "_SWA.pt"
torch.save(temp_net.state_dict(), PATH)

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  99.87654320987654
# Accuracy on  mixed_same  :  90.07407407407408
# Accuracy on  mixed_next  :  76.91358024691358
# Accuracy on  mixed_rand  :  77.62962962962963
# Accuracy on  no_fg  :  48.19753086419753
# Accuracy on  only_bg_b  :  26.37037037037037
# Accuracy on  only_bg_t  :  36.617283950617285
# Accuracy on  only_fg  :  89.11111111111111

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=temp_net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  100.0
# Accuracy on  mixed_same  :  93.87654320987654
# Accuracy on  mixed_next  :  82.0246913580247
# Accuracy on  mixed_rand  :  83.01234567901234
# Accuracy on  no_fg  :  55.72839506172839
# Accuracy on  only_bg_b  :  30.493827160493826
# Accuracy on  only_bg_t  :  37.7037037037037
# Accuracy on  only_fg  :  92.41975308641975

# %%
net.load_state_dict(torch.load("../models/ResNet_base_noSWA.pt"))
# Out:
# <All keys matched successfully>

# %%
n_epoch_first_train = 0
n_cycle = 5
n_epoch_cycle = 2

# %%
make_training(variation,
              net,
              temp_net,
              n_epoch_first_train = n_epoch_first_train,
              n_cycle = n_cycle,
              n_epoch_cycle = n_epoch_cycle,
              batch_size = 16,
              workers = 0,
              criterion = nn.CrossEntropyLoss(),
              test_acc_period = 5,
              _print = False)
# Out:
# using cuda
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# Finished Training
# Final acc :  98.8395061728395
#
# Accuracy Graph
# Loss Graph
# Learning Rate Curve

# %%
PATH = "../models/ResNet_" + str(n_cycle) + "_" + str(n_epoch_cycle)  + "_noSWA.pt"
torch.save(net.state_dict(), PATH)

PATH = "../models/ResNet_" + str(n_cycle)  + "_" + str(n_epoch_cycle)  + "_SWA.pt"
torch.save(temp_net.state_dict(), PATH)

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  93.70370370370371
# Accuracy on  mixed_same  :  79.53086419753086
# Accuracy on  mixed_next  :  68.51851851851852
# Accuracy on  mixed_rand  :  71.30864197530865
# Accuracy on  no_fg  :  35.358024691358025
# Accuracy on  only_bg_b  :  23.506172839506174
# Accuracy on  only_bg_t  :  26.271604938271604
# Accuracy on  only_fg  :  98.8395061728395

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=temp_net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  99.80246913580247
# Accuracy on  mixed_same  :  91.75308641975309
# Accuracy on  mixed_next  :  82.74074074074075
# Accuracy on  mixed_rand  :  84.14814814814815
# Accuracy on  no_fg  :  51.925925925925924
# Accuracy on  only_bg_b  :  25.753086419753085
# Accuracy on  only_bg_t  :  30.691358024691358
# Accuracy on  only_fg  :  100.0

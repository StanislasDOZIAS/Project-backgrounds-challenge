# %%
import sys  
sys.path.insert(0, '../')
from tools.training import make_training, test_on_dataset
from imagenet_models.alexnet import alexnet

import torch.nn as nn
import torch

# %%
variation = "only_bg_t"

# %%
net = alexnet(pretrained=False, progress=True, num_classes = 9)

# %%
make_training(variation = variation, net = net, nb_epoch = 50, batch_size = 16, workers = 0, criterion = nn.CrossEntropyLoss(), test_acc_period = 10, _print = False)
# Out:
# using cuda
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=50.0), HTML(value='')))
# Finished Training
# Final acc :  98.46913580246914
#
# Accuracy Graph
# Loss Graph

# %%
PATH = "../models/AlexNet_"+ variation + ".pt"
torch.save(net.state_dict(), PATH)

# %%
for variation in ["original","mixed_same", "mixed_next", "mixed_rand", "no_fg", "only_bg_b", "only_bg_t", "only_fg"] :
    acc = test_on_dataset(variation = variation, net=net)
    print("Accuracy on ", variation, " : ", acc)
# Out:
# Accuracy on  original  :  28.419753086419753
# Accuracy on  mixed_same  :  43.60493827160494
# Accuracy on  mixed_next  :  7.851851851851852
# Accuracy on  mixed_rand  :  12.148148148148149
# Accuracy on  no_fg  :  19.97530864197531
# Accuracy on  only_bg_b  :  27.061728395061728
# Accuracy on  only_bg_t  :  98.46913580246914
# Accuracy on  only_fg  :  13.11111111111111
